# %% [markdown]
# # Algo Trading Python 2022 QuantProgram

# %% [markdown]
# https://youtu.be/GDMkkmkJigw?list=PLF3MFTbl2HDkZAWXSQ16dqpiNAd4AU74k

# %%
abs(-5)
# Out:
# 5

# %%
# %matplotlib inline
import sys
from datetime import datetime
from datetime import timedelta
import datetime as dt
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# C:\Users\Jonat\AppData\Local\Temp\ipykernel_15096\524056715.py:10: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
ticker=["SPY",
       "SMH","AMD",
       "AAPL",
       "TSM",
       "NVDA"]

# %%
ticker=["SPY", "IWM","QQQ","DIA","FXI", "KWEB",
       "MCHI","IEMG"]#,"TSLA", "SMH"] #"IVV","VOO"

# %%
stocks = pd.read_csv("xxx.csv"), header=[0,1], index_col[0])

# %%
ticker.type()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 ticker.type()
#
# AttributeError: 'list' object has no attribute 'type'

# %%
stocks = yf.download(ticker, start="2023-01-01", end=dt.datetime.today())
# Out:
# [*********************100%***********************]  8 of 8 completed

# %%
stocks.tail()
# Out:
#              Adj Close                                                      \
#                    DIA    FXI       IEMG         IWM       KWEB       MCHI
# Date
# 2023-08-07  354.619995  29.02  50.480000  194.300003  30.100000  47.490002
# 2023-08-08  353.019989  28.48  49.889999  193.080002  29.510000  46.730000
# 2023-08-09  351.279999  28.60  50.049999  191.570007  29.760000  46.889999
# 2023-08-10  351.890015  28.83  50.070000  190.720001  30.030001  47.220001
# 2023-08-11  353.000000  27.92  49.389999  190.990005  28.799999  45.840000
#
#                                          Close         ...        Open  \
#                    QQQ         SPY         DIA    FXI  ...         QQQ
# Date                                                   ...
# 2023-08-07  375.190002  450.709991  354.619995  29.02  ...  373.880005
# 2023-08-08  372.000000  448.750000  353.019989  28.48  ...  372.640015
# 2023-08-09  367.910004  445.750000  351.279999  28.60  ...  372.290009
# ...

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 153 entries, 2023-01-03 to 2023-08-11
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   (Adj Close, IVV)  153 non-null    float64
#  1   (Adj Close, SPY)  153 non-null    float64
#  2   (Adj Close, VOO)  153 non-null    float64
#  3   (Close, IVV)      153 non-null    float64
#  4   (Close, SPY)      153 non-null    float64
#  5   (Close, VOO)      153 non-null    float64
#  6   (High, IVV)       153 non-null    float64
#  7   (High, SPY)       153 non-null    float64
#  8   (High, VOO)       153 non-null    float64
#  9   (Low, IVV)        153 non-null    float64
#  10  (Low, SPY)        153 non-null    float64
#  11  (Low, VOO)        153 non-null    float64
#  12  (Open, IVV)       153 non-null    float64
#  13  (Open, SPY)       153 non-null    float64
#  14  (Open, VOO)       153 non-null    float64
# ...

# %%
stocks.describe()
# Out:
#         Adj Close                                           Close              \
#              AAPL        NVDA         SPY         TSM        AAPL        NVDA
# count  486.000000  486.000000  486.000000  486.000000  486.000000  486.000000
# mean   147.468982  191.306988  411.400938  103.395483  148.319280  191.491713
# std     15.718698   53.626152   29.121204   17.816710   15.566448   53.675139
# min    115.151550  112.241280  354.930145   59.940254  116.360001  112.269997
# 25%    135.269768  146.330952  385.779808   87.805397  136.427502  146.504375
# 50%    147.093307  181.580368  409.997330  110.942524  147.940002  181.700005
# 75%    158.867962  223.168968  434.130722  116.139708  159.757500  223.405003
# max    180.959747  333.407379  470.083679  137.687866  182.009995  333.760010
#
#                                      High              ...         Low  \
#               SPY         TSM        AAPL        NVDA  ...         SPY
# ...

# %%
close=stocks.loc[:,"Close"].copy()   # :  takes all rows from the "Close column"
close
# Out:
#                    DIA        FXI       IEMG         IWM       KWEB  \
# Date
# 2023-01-03  331.220001  29.320000  47.070000  173.399994  31.799999
# 2023-01-04  332.559998  31.190001  48.439999  175.559998  34.599998
# 2023-01-05  329.220001  31.120001  48.200001  173.679993  34.759998
# 2023-01-06  336.279999  31.200001  49.240002  177.580002  34.570000
# 2023-01-09  335.290009  31.200001  49.590000  177.880005  34.610001
# ...                ...        ...        ...         ...        ...
# 2023-08-07  354.619995  29.020000  50.480000  194.300003  30.100000
# 2023-08-08  353.019989  28.480000  49.889999  193.080002  29.510000
# 2023-08-09  351.279999  28.600000  50.049999  191.570007  29.760000
# 2023-08-10  351.890015  28.830000  50.070000  190.720001  30.030001
# 2023-08-11  353.000000  27.920000  49.389999  190.990005  28.799999
#
#                  MCHI         QQQ         SPY
# Date
# 2023-01-03  49.110001  264.480011  380.820007
# ...

# %%
#manipulate in csv
stocks.tail()
# Out:
#              Adj Close                                                      \
#                    DIA    FXI       IEMG         IWM       KWEB       MCHI
# Date
# 2023-08-07  354.619995  29.02  50.480000  194.300003  30.100000  47.490002
# 2023-08-08  353.019989  28.48  49.889999  193.080002  29.510000  46.730000
# 2023-08-09  351.279999  28.60  50.049999  191.570007  29.760000  46.889999
# 2023-08-10  351.890015  28.83  50.070000  190.720001  30.030001  47.220001
# 2023-08-11  353.000000  27.92  49.389999  190.990005  28.799999  45.840000
#
#                                          Close         ...        Open  \
#                    QQQ         SPY         DIA    FXI  ...         QQQ
# Date                                                   ...
# 2023-08-07  375.190002  450.709991  354.619995  29.02  ...  373.880005
# 2023-08-08  372.000000  448.750000  353.019989  28.48  ...  372.640015
# 2023-08-09  367.910004  445.750000  351.279999  28.60  ...  372.290009
# ...

# %%
stocks.to_csv("algo.csv")

# %%
stocks = pd.read_csv("algo.csv")
stocks.tail()
# Out:
#      Unnamed: 0          Adj Close         Adj Close.1        Adj Close.2  \
# 150  2023-08-07  354.6199951171875  29.020000457763672  50.47999954223633
# 151  2023-08-08  353.0199890136719  28.479999542236328  49.88999938964844
# 152  2023-08-09  351.2799987792969  28.600000381469727  50.04999923706055
# 153  2023-08-10  351.8900146484375  28.829999923706055  50.06999969482422
# 154  2023-08-11              353.0  27.920000076293945  49.38999938964844
#
#             Adj Close.3         Adj Close.4         Adj Close.5  \
# 150   194.3000030517578  30.100000381469727    47.4900016784668
# 151   193.0800018310547  29.510000228881836   46.72999954223633
# 152  191.57000732421875  29.760000228881836   46.88999938964844
# 153  190.72000122070312  30.030000686645508  47.220001220703125
# 154  190.99000549316406  28.799999237060547   45.84000015258789
#
#             Adj Close.6        Adj Close.7              Close  ...  \
# ...

# %%
stocks = pd.read_csv("algo.csv",header=[0,1], index_col=[0], parse_dates=[0])
stocks.tail()
# Out:
#              Adj Close                                                      \
#                    DIA    FXI       IEMG         IWM       KWEB       MCHI
# Date
# 2023-08-07  354.619995  29.02  50.480000  194.300003  30.100000  47.490002
# 2023-08-08  353.019989  28.48  49.889999  193.080002  29.510000  46.730000
# 2023-08-09  351.279999  28.60  50.049999  191.570007  29.760000  46.889999
# 2023-08-10  351.890015  28.83  50.070000  190.720001  30.030001  47.220001
# 2023-08-11  353.000000  27.92  49.389999  190.990005  28.799999  45.840000
#
#                                          Close         ...        Open  \
#                    QQQ         SPY         DIA    FXI  ...         QQQ
# Date                                                   ...
# 2023-08-07  375.190002  450.709991  354.619995  29.02  ...  373.880005
# 2023-08-08  372.000000  448.750000  353.019989  28.48  ...  372.640015
# 2023-08-09  367.910004  445.750000  351.279999  28.60  ...  372.290009
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'AMD'),
#             ('Adj Close', 'NVDA'),
#             ('Adj Close',  'SMH'),
#             ('Adj Close',  'SPY'),
#             ('Adj Close',  'TSM'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'AMD'),
#             (    'Close', 'NVDA'),
#             (    'Close',  'SMH'),
#             (    'Close',  'SPY'),
#             (    'Close',  'TSM'),
#             (     'High', 'AAPL'),
#             (     'High',  'AMD'),
#             (     'High', 'NVDA'),
#             (     'High',  'SMH'),
#             (     'High',  'SPY'),
#             (     'High',  'TSM'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'AMD'),
#             (      'Low', 'NVDA'),
#             (      'Low',  'SMH'),
#             (      'Low',  'SPY'),
#             (      'Low',  'TSM'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'AMD'),
#             (     'Open', 'NVDA'),
# ...

# %%
#convert multiindex to tuple
stocks.columns = stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),  ('Adj Close', 'DIA'),  ('Adj Close', 'FXI'),
#         ('Adj Close', 'IVV'),  ('Adj Close', 'IWM'), ('Adj Close', 'KWEB'),
#         ('Adj Close', 'QQQ'),  ('Adj Close', 'SMH'),  ('Adj Close', 'SPY'),
#        ('Adj Close', 'TSLA'),  ('Adj Close', 'TSM'),  ('Adj Close', 'VOO'),
#            ('Close', 'AAPL'),      ('Close', 'DIA'),      ('Close', 'FXI'),
#             ('Close', 'IVV'),      ('Close', 'IWM'),     ('Close', 'KWEB'),
#             ('Close', 'QQQ'),      ('Close', 'SMH'),      ('Close', 'SPY'),
#            ('Close', 'TSLA'),      ('Close', 'TSM'),      ('Close', 'VOO'),
#             ('High', 'AAPL'),       ('High', 'DIA'),       ('High', 'FXI'),
#              ('High', 'IVV'),       ('High', 'IWM'),      ('High', 'KWEB'),
#              ('High', 'QQQ'),       ('High', 'SMH'),       ('High', 'SPY'),
#             ('High', 'TSLA'),       ('High', 'TSM'),       ('High', 'VOO'),
# ...

# %%
stocks.head()
# Out:
#             (Adj Close, IVV)  (Adj Close, SPY)  (Adj Close, VOO)  \
# Date
# 2023-01-03        379.749695        377.968140        347.190247
# 2023-01-04        382.708038        380.886139        349.690094
# 2023-01-05        378.359863        376.538910        345.870880
# 2023-01-06        386.996613        385.173737        353.737457
# 2023-01-09        386.728577        384.955383        353.479523
#
#             (Close, IVV)  (Close, SPY)  (Close, VOO)  (High, IVV)  \
# Date
# 2023-01-03    382.529999    380.820007    349.989990   388.109985
# 2023-01-04    385.510010    383.760010    352.510010   387.630005
# 2023-01-05    381.130005    379.380005    348.660004   383.549988
# 2023-01-06    389.829987    388.079987    356.589996   391.029999
# 2023-01-09    389.559998    387.859985    356.329987   395.500000
#
#             (High, SPY)  (High, VOO)  (Low, IVV)  (Low, SPY)  (Low, VOO)  \
# Date
# 2023-01-03   386.429993   355.040009  379.600006  377.829987  347.190002
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks.head() #undo
# Out:
#              Adj Close                                               \
#                    DIA        FXI       IEMG         IWM       KWEB
# Date
# 2023-01-03  327.641144  29.158682  46.611820  172.285416  31.799999
# 2023-01-04  328.966675  31.018394  47.968487  174.431534  34.599998
# 2023-01-05  325.662781  30.948778  47.730824  172.563614  34.759998
# 2023-01-06  332.646545  31.028339  48.760700  176.438553  34.570000
# 2023-01-09  331.667206  31.028339  49.107292  176.736633  34.610001
#
#                                                     Close             ...  \
#                  MCHI         QQQ         SPY         DIA        FXI  ...
# Date                                                                  ...
# 2023-01-03  48.651897  263.709473  377.968140  331.220001  29.320000  ...
# 2023-01-04  51.524841  264.965759  380.886139  332.559998  31.190001  ...
# 2023-01-05  51.485218  260.817902  376.538910  329.220001  31.120001  ...
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'IVV'),
#             ('Adj Close', 'SPY'),
#             ('Adj Close', 'VOO'),
#             (    'Close', 'IVV'),
#             (    'Close', 'SPY'),
#             (    'Close', 'VOO'),
#             (     'High', 'IVV'),
#             (     'High', 'SPY'),
#             (     'High', 'VOO'),
#             (      'Low', 'IVV'),
#             (      'Low', 'SPY'),
#             (      'Low', 'VOO'),
#             (     'Open', 'IVV'),
#             (     'Open', 'SPY'),
#             (     'Open', 'VOO'),
#             (   'Volume', 'IVV'),
#             (   'Volume', 'SPY'),
#             (   'Volume', 'VOO')],
#            )

# %%
stocks.describe()
# Out:
#         Adj Close                                                              \
#              AAPL         AMD        NVDA         SMH         SPY         TSM
# count  569.000000  569.000000  569.000000  569.000000  569.000000  569.000000
# mean   147.046620   94.419385  193.685143  242.037581  407.783963  100.528442
# std     15.099721   22.272193   52.349371   28.766496   27.527022   17.523843
# min    114.976013   55.939999  112.222221  171.203491  353.580688   59.629837
# 25%    135.133362   78.580002  150.830948  225.130386  385.331512   86.619087
# 50%    146.895889   89.739998  186.345276  242.361740  405.639038  105.959160
# 75%    157.457993  106.220001  226.941452  258.748169  429.349335  114.445534
# max    180.683853  161.910004  333.350769  313.001343  468.296417  136.974823
#
#             Close                                      ...        Open  \
#              AAPL         AMD        NVDA         SMH  ...        NVDA
# ...

# %%
close.iloc[0,0]
# Out:
# 129.41000366210938

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.SPY
# Out:
# Date
# 2023-01-03    380.820007
# 2023-01-04    383.760010
# 2023-01-05    379.380005
# 2023-01-06    388.079987
# 2023-01-09    387.859985
#                  ...
# 2023-08-07    450.709991
# 2023-08-08    448.750000
# 2023-08-09    445.750000
# 2023-08-10    445.910004
# 2023-08-11    445.649994
# Name: SPY, Length: 153, dtype: float64

# %%
close.iloc[0,2]
# Out:
# 47.06999969482422

# %%
#to normalise data
close.SPY.div(close.iloc[0,2])
# Out:
# Date
# 2023-01-03    8.090504
# 2023-01-04    8.152964
# 2023-01-05    8.059911
# 2023-01-06    8.244742
# 2023-01-09    8.240068
#                 ...
# 2023-08-07    9.575313
# 2023-08-08    9.533673
# 2023-08-09    9.469938
# 2023-08-10    9.473338
# 2023-08-11    9.467814
# Name: SPY, Length: 153, dtype: float64

# %%
close.SPY.div(close.iloc[0,2]).mul(100)
# Out:
# Date
# 2023-01-03    809.050371
# 2023-01-04    815.296393
# 2023-01-05    805.991093
# 2023-01-06    824.474164
# 2023-01-09    824.006773
#                  ...
# 2023-08-07    957.531324
# 2023-08-08    953.367331
# 2023-08-09    946.993845
# 2023-08-10    947.333772
# 2023-08-11    946.781383
# Name: SPY, Length: 153, dtype: float64

# %%
normclose=close.SPY.div(close.iloc[0,2]).mul(100)

# %%
close.iloc[0]
# Out:
# DIA     331.220001
# FXI      29.320000
# IEMG     47.070000
# IWM     173.399994
# KWEB     31.799999
# MCHI     49.110001
# QQQ     264.480011
# SPY     380.820007
# Name: 2023-01-03 00:00:00, dtype: float64

# %%
normclose = close.div(close.iloc[0]).mul(100)
normclose
# Out:
#                    DIA         FXI        IEMG         IWM        KWEB  \
# Date
# 2023-01-03  100.000000  100.000000  100.000000  100.000000  100.000000
# 2023-01-04  100.404564  106.377902  102.910556  101.245677  108.805029
# 2023-01-05   99.396172  106.139158  102.400682  100.161476  109.308173
# 2023-01-06  101.527685  106.412009  104.610159  102.410616  108.710693
# 2023-01-09  101.228793  106.412009  105.353729  102.583628  108.836483
# ...                ...         ...         ...         ...         ...
# 2023-08-07  107.064789   98.976810  107.244529  112.053062   94.654092
# 2023-08-08  106.581724   97.135061  105.991077  111.349486   92.798745
# 2023-08-09  106.056397   97.544341  106.330995  110.478670   93.584909
# 2023-08-10  106.240569   98.328787  106.373486  109.988471   94.433967
# 2023-08-11  106.575689   95.225104  104.928829  110.144182   90.566038
#
#                   MCHI         QQQ         SPY
# Date
# 2023-01-03  100.000000  100.000000  100.000000
# ...

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
# Add text labels to the plot
for col in normclose.columns:
    x = normclose.index[-1]
    y = normclose[col].iloc[-1]
    plt.text(x, y, col)
plt.show()

# %% [markdown]
# # LAG

# %%
aapl = close.AAPL.copy().to_frame()
aapl.head()
# Out:
#                   AAPL
# Date
# 2021-01-04  129.410004
# 2021-01-05  131.009995
# 2021-01-06  126.599998
# 2021-01-07  130.919998
# 2021-01-08  132.050003

# %%
aapl.shift(periods=1)
# Out:
#                   AAPL
# Date
# 2021-01-04         NaN
# 2021-01-05  129.410004
# 2021-01-06  131.009995
# 2021-01-07  126.599998
# 2021-01-08  130.919998
# ...                ...
# 2023-03-31  162.360001
# 2023-04-03  164.899994
# 2023-04-04  166.169998
# 2023-04-05  165.630005
# 2023-04-06  163.759995
#
# [569 rows x 1 columns]

# %%
aapl["lag1"] = aapl.shift(periods=1)
aapl.head()
# Out:
#                   AAPL        lag1
# Date
# 2021-01-04  129.410004         NaN
# 2021-01-05  131.009995  129.410004
# 2021-01-06  126.599998  131.009995
# 2021-01-07  130.919998  126.599998
# 2021-01-08  132.050003  130.919998

# %%
#same same
aapl.AAPL.sub(aapl.lag1)
# Out:
# Date
# 2021-01-04         NaN
# 2021-01-05    1.599991
# 2021-01-06   -4.409996
# 2021-01-07    4.320000
# 2021-01-08    1.130005
#                 ...
# 2023-03-31    2.539993
# 2023-04-03    1.270004
# 2023-04-04   -0.539993
# 2023-04-05   -1.870010
# 2023-04-06    0.900009
# Length: 569, dtype: float64

# %%
aapl['diff'] = aapl.AAPL.sub(aapl.lag1)
aapl.tail()
# Out:
#                   AAPL        lag1      diff
# Date
# 2023-03-31  164.899994  162.360001  2.539993
# 2023-04-03  166.169998  164.899994  1.270004
# 2023-04-04  165.630005  166.169998 -0.539993
# 2023-04-05  163.759995  165.630005 -1.870010
# 2023-04-06  164.660004  163.759995  0.900009

# %%
aapl.AAPL.div(aapl.lag1)
# Out:
# Date
# 2021-01-04         NaN
# 2021-01-05    1.012364
# 2021-01-06    0.966338
# 2021-01-07    1.034123
# 2021-01-08    1.008631
#                 ...
# 2023-03-31    1.015644
# 2023-04-03    1.007702
# 2023-04-04    0.996750
# 2023-04-05    0.988710
# 2023-04-06    1.005496
# Length: 569, dtype: float64

# %%
aapl["pct change"] = aapl.AAPL.div(aapl.lag1).sub(1).mul(100)
aapl
# Out:
#                   AAPL        lag1      diff  pct change  % change 2
# Date
# 2021-01-04  129.410004         NaN       NaN         NaN         NaN
# 2021-01-05  131.009995  129.410004  1.599991    1.236373    1.236373
# 2021-01-06  126.599998  131.009995 -4.409996   -3.366152   -3.366152
# 2021-01-07  130.919998  126.599998  4.320000    3.412322    3.412322
# 2021-01-08  132.050003  130.919998  1.130005    0.863126    0.863126
# ...                ...         ...       ...         ...         ...
# 2023-03-31  164.899994  162.360001  2.539993    1.564421    1.564421
# 2023-04-03  166.169998  164.899994  1.270004    0.770166    0.770166
# 2023-04-04  165.630005  166.169998 -0.539993   -0.324964   -0.324964
# 2023-04-05  163.759995  165.630005 -1.870010   -1.129029   -1.129029
# 2023-04-06  164.660004  163.759995  0.900009    0.549590    0.549590
#
# [569 rows x 5 columns]

# %%
aapl["% change 2"] = aapl.AAPL.pct_change(periods=1).mul(100)  #BETTER
aapl
# Out:
#                   AAPL        lag1      diff  pct change  % change 2
# Date
# 2021-01-04  129.410004         NaN       NaN         NaN         NaN
# 2021-01-05  131.009995  129.410004  1.599991    1.236373    1.236373
# 2021-01-06  126.599998  131.009995 -4.409996   -3.366152   -3.366152
# 2021-01-07  130.919998  126.599998  4.320000    3.412322    3.412322
# 2021-01-08  132.050003  130.919998  1.130005    0.863126    0.863126
# ...                ...         ...       ...         ...         ...
# 2023-03-31  164.899994  162.360001  2.539993    1.564421    1.564421
# 2023-04-03  166.169998  164.899994  1.270004    0.770166    0.770166
# 2023-04-04  165.630005  166.169998 -0.539993   -0.324964   -0.324964
# 2023-04-05  163.759995  165.630005 -1.870010   -1.129029   -1.129029
# 2023-04-06  164.660004  163.759995  0.900009    0.549590    0.549590
#
# [569 rows x 5 columns]

# %%
pct_change()

# %%
aapl["% change"] = (aapl["AAPL"] - aapl["AAPL"].shift(1)) / aapl["AAPL"].shift(1)*100    #cleaner
aapl
# Out:
#                   AAPL        lag1      diff  pct change  % change 2  % change
# Date
# 2021-01-04  129.410004         NaN       NaN         NaN         NaN       NaN
# 2021-01-05  131.009995  129.410004  1.599991    1.236373    1.236373  1.236373
# 2021-01-06  126.599998  131.009995 -4.409996   -3.366152   -3.366152 -3.366152
# 2021-01-07  130.919998  126.599998  4.320000    3.412322    3.412322  3.412322
# 2021-01-08  132.050003  130.919998  1.130005    0.863126    0.863126  0.863126
# ...                ...         ...       ...         ...         ...       ...
# 2023-03-31  164.899994  162.360001  2.539993    1.564421    1.564421  1.564421
# 2023-04-03  166.169998  164.899994  1.270004    0.770166    0.770166  0.770166
# 2023-04-04  165.630005  166.169998 -0.539993   -0.324964   -0.324964 -0.324964
# 2023-04-05  163.759995  165.630005 -1.870010   -1.129029   -1.129029 -1.129029
# 2023-04-06  164.660004  163.759995  0.900009    0.549590    0.549590  0.549590
#
# ...

# %%
#delete column
del aapl["% change"]
del aapl["pct change"]
del aapl["lag1"]
del aapl["diff"]
aapl
# Out:
#                   AAPL  % change 2
# Date
# 2021-01-04  129.410004         NaN
# 2021-01-05  131.009995    1.236373
# 2021-01-06  126.599998   -3.366152
# 2021-01-07  130.919998    3.412322
# 2021-01-08  132.050003    0.863126
# ...                ...         ...
# 2023-03-31  164.899994    1.564421
# 2023-04-03  166.169998    0.770166
# 2023-04-04  165.630005   -0.324964
# 2023-04-05  163.759995   -1.129029
# 2023-04-06  164.660004    0.549590
#
# [569 rows x 2 columns]

# %%
#rename
aapl.rename(columns = {'AAPL' : 'aapl'}, inplace = True)  #check the STI example for renaming bulk
aapl.rename(columns = {'% change 2' : 'Change'}, inplace = True)
aapl.head()
# Out:
#                   aapl    Change
# Date
# 2021-01-04  129.410004       NaN
# 2021-01-05  131.009995  1.236373
# 2021-01-06  126.599998 -3.366152
# 2021-01-07  130.919998  3.412322
# 2021-01-08  132.050003  0.863126

# %%
aapl.aapl.resample("M").last() #data for every last day of mo
# Out:
# Date
# 2021-01-31    131.960007
# 2021-02-28    121.260002
# 2021-03-31    122.150002
# 2021-04-30    131.460007
# 2021-05-31    124.610001
# 2021-06-30    136.960007
# 2021-07-31    145.860001
# 2021-08-31    151.830002
# 2021-09-30    141.500000
# 2021-10-31    149.800003
# 2021-11-30    165.300003
# 2021-12-31    177.570007
# 2022-01-31    174.779999
# 2022-02-28    165.119995
# 2022-03-31    174.610001
# 2022-04-30    157.649994
# 2022-05-31    148.839996
# 2022-06-30    136.720001
# 2022-07-31    162.509995
# 2022-08-31    157.220001
# 2022-09-30    138.199997
# 2022-10-31    153.339996
# 2022-11-30    148.029999
# 2022-12-31    142.910004
# Freq: M, Name: aapl, dtype: float64

# %%
aapl.aapl.resample("BM").last() #last biz day
# Out:
# Date
# 2021-01-29    131.960007
# 2021-02-26    121.260002
# 2021-03-31    122.150002
# 2021-04-30    131.460007
# 2021-05-31    124.610001
# 2021-06-30    136.960007
# 2021-07-30    145.860001
# 2021-08-31    151.830002
# 2021-09-30    141.500000
# 2021-10-29    149.800003
# 2021-11-30    165.300003
# 2021-12-31    177.570007
# 2022-01-31    174.779999
# 2022-02-28    165.119995
# 2022-03-31    174.610001
# 2022-04-29    157.649994
# 2022-05-31    148.839996
# 2022-06-30    136.720001
# 2022-07-29    162.509995
# 2022-08-31    157.220001
# 2022-09-30    138.199997
# 2022-10-31    153.339996
# 2022-11-30    148.029999
# 2022-12-30    142.910004
# Freq: BM, Name: aapl, dtype: float64

# %%
aapl.aapl.resample("BM").last().pct_change(periods=1)*100  #% change
# Out:
# Date
# 2021-01-29          NaN
# 2021-02-26    -8.108521
# 2021-03-31     0.733960
# 2021-04-30     7.621781
# 2021-05-31    -5.210715
# 2021-06-30     9.910927
# 2021-07-30     6.498243
# 2021-08-31     4.092967
# 2021-09-30    -6.803663
# 2021-10-29     5.865727
# 2021-11-30    10.347129
# 2021-12-31     7.422870
# 2022-01-31    -1.571216
# 2022-02-28    -5.526950
# 2022-03-31     5.747339
# 2022-04-29    -9.713079
# 2022-05-31    -5.588327
# 2022-06-30    -8.142969
# 2022-07-29    18.863365
# 2022-08-31    -3.255180
# 2022-09-30   -12.097700
# 2022-10-31    10.955137
# 2022-11-30    -3.462891
# 2022-12-30    -3.458755
# Freq: BM, Name: aapl, dtype: float64

# %%
del aapl['Change']

# %%
aapl
# Out:
#                   aapl
# Date
# 2021-01-04  129.410004
# 2021-01-05  131.009995
# 2021-01-06  126.599998
# 2021-01-07  130.919998
# 2021-01-08  132.050003
# ...                ...
# 2023-03-31  164.899994
# 2023-04-03  166.169998
# 2023-04-04  165.630005
# 2023-04-05  163.759995
# 2023-04-06  164.660004
#
# [569 rows x 1 columns]

# %%
ret = aapl.pct_change().dropna()
ret
# Out:
#                 aapl
# Date
# 2021-01-05  0.012364
# 2021-01-06 -0.033662
# 2021-01-07  0.034123
# 2021-01-08  0.008631
# 2021-01-11 -0.023249
# ...              ...
# 2023-03-31  0.015644
# 2023-04-03  0.007702
# 2023-04-04 -0.003250
# 2023-04-05 -0.011290
# 2023-04-06  0.005496
#
# [568 rows x 1 columns]

# %%
ret.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 568 entries, 2021-01-05 to 2023-04-06
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   aapl    568 non-null    float64
# dtypes: float64(1)
# memory usage: 8.9 KB

# %%
ret.plot(kind = "hist", figsize=(12,8), bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
daily_mean_ret=ret.mean()
daily_mean_ret
# Out:
# aapl    0.000604
# dtype: float64

# %%
var_daily = ret.var()
var_daily
# Out:
# aapl    0.000361
# dtype: float64

# %%
std_daily = np.sqrt(var_daily)
std_daily
# Out:
# aapl    0.018993
# dtype: float64

# %%
ret.std() #same
# Out:
# aapl    0.018993
# dtype: float64

# %%
ann_mean_ret = daily_mean_ret*252
ann_mean_ret
# Out:
# aapl    0.152205
# dtype: float64

# %%
ann_var_return = var_daily*252
ann_var_return
# Out:
# aapl    0.090908
# dtype: float64

# %%
ann_std_ret = np.sqrt(ann_var_return)
ann_std_ret
# Out:
# aapl    0.30151
# dtype: float64

# %%
ret.std()*np.sqrt(252)
# Out:
# aapl    0.30151
# dtype: float64

# %%
ticker = ["SPY", "AAPL", "NVDA", "MSFT", "AMD", "TLT", "XOM", "XLE", "DVN"]

# %%
stocks = yf.download(ticker, start="2021-01-01", end=dt.datetime.today())
# Out:
# [*********************100%***********************]  9 of 9 completed

# %%
close = stocks.loc[:,"Close"].copy()

# %%
close.head()
# Out:
#                   AAPL        AMD        DVN        MSFT        NVDA  \
# Date
# 2021-01-04  129.410004  92.300003  16.129999  217.690002  131.134995
# 2021-01-05  131.009995  92.769997  17.360001  217.899994  134.047501
# 2021-01-06  126.599998  90.330002  18.320000  212.250000  126.144997
# 2021-01-07  130.919998  95.160004  18.570000  218.289993  133.440002
# 2021-01-08  132.050003  94.580002  18.110001  219.619995  132.767502
#
#                    SPY         TLT        XLE        XOM
# Date
# 2021-01-04  368.790009  157.539993  37.959999  41.500000
# 2021-01-05  371.329987  156.369995  39.660000  43.500000
# 2021-01-06  373.549988  153.160004  40.869999  44.610001
# 2021-01-07  379.100006  151.809998  41.470001  44.959999
# 2021-01-08  381.260010  151.320007  41.419998  45.459999

# %%
normclose=close.div(close.iloc[0]).mul(100)

# %%
normclose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
# Add text labels to the plot
for col in normclose.columns:
    x = normclose.index[-1]
    y = normclose[col].iloc[-1]
    plt.text(x, y, col)
plt.show()

# %%
ret=close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL       AMD       DVN      MSFT      NVDA       SPY  \
# Date
# 2021-01-05  0.012364  0.005092  0.076256  0.000965  0.022210  0.006887
# 2021-01-06 -0.033662 -0.026302  0.055299 -0.025929 -0.058953  0.005979
# 2021-01-07  0.034123  0.053471  0.013646  0.028457  0.057830  0.014857
# 2021-01-08  0.008631 -0.006095 -0.024771  0.006093 -0.005040  0.005698
# 2021-01-11 -0.023249  0.028230  0.012148 -0.009699  0.025966 -0.006741
#
#                  TLT       XLE       XOM
# Date
# 2021-01-05 -0.007427  0.044784  0.048193
# 2021-01-06 -0.020528  0.030509  0.025517
# 2021-01-07 -0.008814  0.014681  0.007846
# 2021-01-08 -0.003228 -0.001206  0.011121
# 2021-01-11 -0.001652  0.015693  0.030356

# %%
stocks.tail()
# Out:
#              Adj Close                                                \
#                   AAPL        AMD        DVN        MSFT        NVDA
# Date
# 2023-04-04  165.630005  95.870003  52.740002  287.179993  274.529999
# 2023-04-05  163.759995  92.559998  53.529999  284.339996  268.809998
# 2023-04-06  164.660004  92.470001  52.910000  291.600006  270.369995
# 2023-04-10  162.029999  95.480003  53.389999  289.390015  275.790009
# 2023-04-11  161.309998  93.440002  54.615002  283.299988  272.790009
#
#                                                                 Close  ...  \
#                    SPY         TLT        XLE         XOM        AAPL  ...
# Date                                                                   ...
# 2023-04-04  408.670013  107.129997  85.010002  115.019997  165.630005  ...
# 2023-04-05  407.600006  108.250000  86.290001  116.989998  163.759995  ...
# 2023-04-06  409.190002  108.529999  84.980003  115.050003  164.660004  ...
# ...

# %%
ret.describe()
# Out:
#              AAPL         AMD         DVN        MSFT        NVDA         SPY  \
# count  570.000000  570.000000  570.000000  570.000000  570.000000  570.000000
# mean     0.000566    0.000568    0.002685    0.000631    0.001880    0.000260
# std      0.018974    0.033107    0.032998    0.018408    0.034598    0.012066
# min     -0.058680   -0.138688   -0.127555   -0.077156   -0.094726   -0.043482
# 25%     -0.010591   -0.019688   -0.016671   -0.009454   -0.019045   -0.006608
# 50%      0.000757   -0.000981    0.001676   -0.000170    0.002670    0.000370
# 75%      0.012925    0.020429    0.021297    0.012030    0.022153    0.007697
# max      0.088975    0.142690    0.137048    0.082268    0.143293    0.054954
#
#               TLT         XLE         XOM
# count  570.000000  570.000000  570.000000
# mean    -0.000621    0.001657    0.002011
# std      0.011082    0.020214    0.020344
# min     -0.034183   -0.082730   -0.078853
# 25%     -0.008143   -0.010619   -0.011073
# ...

# %%
#transpose
ret.describe().T
# Out:
#       count      mean       std       min       25%       50%       75%  \
# AAPL  570.0  0.000566  0.018974 -0.058680 -0.010591  0.000757  0.012925
# AMD   570.0  0.000568  0.033107 -0.138688 -0.019688 -0.000981  0.020429
# DVN   570.0  0.002685  0.032998 -0.127555 -0.016671  0.001676  0.021297
# MSFT  570.0  0.000631  0.018408 -0.077156 -0.009454 -0.000170  0.012030
# NVDA  570.0  0.001880  0.034598 -0.094726 -0.019045  0.002670  0.022153
# SPY   570.0  0.000260  0.012066 -0.043482 -0.006608  0.000370  0.007697
# TLT   570.0 -0.000621  0.011082 -0.034183 -0.008143 -0.001113  0.006660
# XLE   570.0  0.001657  0.020214 -0.082730 -0.010619  0.002077  0.014952
# XOM   570.0  0.002011  0.020344 -0.078853 -0.011073  0.002179  0.014443
#
#            max
# AAPL  0.088975
# AMD   0.142690
# DVN   0.137048
# MSFT  0.082268
# NVDA  0.143293
# SPY   0.054954
# TLT   0.038474
# XLE   0.056512
# XOM   0.064113

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#           mean       std
# AAPL  0.000566  0.018974
# AMD   0.000568  0.033107
# DVN   0.002685  0.032998
# MSFT  0.000631  0.018408
# NVDA  0.001880  0.034598
# SPY   0.000260  0.012066
# TLT  -0.000621  0.011082
# XLE   0.001657  0.020214
# XOM   0.002011  0.020344

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.142645  0.301200
# AMD   0.143023  0.525555
# DVN   0.676704  0.523820
# MSFT  0.159097  0.292220
# NVDA  0.473716  0.549230
# SPY   0.065447  0.191540
# TLT  -0.156485  0.175919
# XLE   0.417447  0.320883
# XOM   0.506818  0.322949

# %%
summary.plot.scatter(x="std",y="mean", figsize=(12,8), s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i, xy=(summary.loc[i,"std"]+0.009, summary.loc[i,"mean"]+0.005),size=15)
plt.xlabel("Annual risk(std)", fontsize = 15)
plt.ylabel("Annual Return", fontsize = 15)
plt.title("Risk/Return", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Risk/Return')

# %%
#for loops
fruits = ["durian", "coconut", "banana"]
for i in fruits:
    print(i)
# Out:
# durian
# coconut
# banana

# %% [markdown]
# ## Covariance & Correlation

# %%
ret
# Out:
#                 AAPL       AMD       DVN      MSFT      NVDA       SPY  \
# Date
# 2021-01-05  0.012364  0.005092  0.076256  0.000965  0.022210  0.006887
# 2021-01-06 -0.033662 -0.026302  0.055299 -0.025929 -0.058953  0.005979
# 2021-01-07  0.034123  0.053471  0.013646  0.028457  0.057830  0.014857
# 2021-01-08  0.008631 -0.006095 -0.024771  0.006093 -0.005040  0.005698
# 2021-01-11 -0.023249  0.028230  0.012148 -0.009699  0.025966 -0.006741
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-04 -0.003250 -0.007146 -0.010692 -0.000174 -0.018309 -0.005548
# 2023-04-05 -0.011290 -0.034526  0.014979 -0.009889 -0.020836 -0.002618
# 2023-04-06  0.005496 -0.000972 -0.011582  0.025533  0.005803  0.003901
# 2023-04-10 -0.015972  0.032551  0.009072 -0.007579  0.020047  0.001026
# 2023-04-11 -0.004444 -0.021366  0.022944 -0.021044 -0.010878  0.001586
#
#                  TLT       XLE       XOM
# Date
# 2021-01-05 -0.007427  0.044784  0.048193
# ...

# %%
ret.cov()
# Out:
#           AAPL       AMD       DVN      MSFT      NVDA       SPY       TLT  \
# AAPL  0.000360  0.000394  0.000136  0.000264  0.000439  0.000187  0.000012
# AMD   0.000394  0.001096  0.000265  0.000396  0.000949  0.000284  0.000025
# DVN   0.000136  0.000265  0.001089  0.000113  0.000286  0.000159 -0.000044
# MSFT  0.000264  0.000396  0.000113  0.000339  0.000453  0.000181  0.000021
# NVDA  0.000439  0.000949  0.000286  0.000453  0.001197  0.000312  0.000038
# SPY   0.000187  0.000284  0.000159  0.000181  0.000312  0.000146  0.000003
# TLT   0.000012  0.000025 -0.000044  0.000021  0.000038  0.000003  0.000123
# XLE   0.000085  0.000151  0.000585  0.000068  0.000155  0.000107 -0.000043
# XOM   0.000076  0.000105  0.000524  0.000052  0.000112  0.000093 -0.000044
#
#            XLE       XOM
# AAPL  0.000085  0.000076
# AMD   0.000151  0.000105
# DVN   0.000585  0.000524
# MSFT  0.000068  0.000052
# NVDA  0.000155  0.000112
# SPY   0.000107  0.000093
# TLT  -0.000043 -0.000044
# ...

# %%
ret.corr()
# Out:
#           AAPL       AMD       DVN      MSFT      NVDA       SPY       TLT  \
# AAPL  1.000000  0.627105  0.217221  0.757239  0.668751  0.817825  0.057913
# AMD   0.627105  1.000000  0.242154  0.650550  0.828658  0.710395  0.067670
# DVN   0.217221  0.242154  1.000000  0.185650  0.250731  0.399333 -0.118968
# MSFT  0.757239  0.650550  0.185650  1.000000  0.711135  0.816827  0.102687
# NVDA  0.668751  0.828658  0.250731  0.711135  1.000000  0.748482  0.099013
# SPY   0.817825  0.710395  0.399333  0.816827  0.748482  1.000000  0.018818
# TLT   0.057913  0.067670 -0.118968  0.102687  0.099013  0.018818  1.000000
# XLE   0.222575  0.225260  0.876579  0.182007  0.221529  0.438584 -0.193584
# XOM   0.197073  0.155419  0.780284  0.139891  0.159013  0.379802 -0.197169
#
#            XLE       XOM
# AAPL  0.222575  0.197073
# AMD   0.225260  0.155419
# DVN   0.876579  0.780284
# MSFT  0.182007  0.139891
# NVDA  0.221529  0.159013
# SPY   0.438584  0.379802
# TLT  -0.193584 -0.197169
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(), cmap="Reds", annot=True, annot_kws={"size":15},vmax=0.5)
plt.show()  #anything <0.5 is less correlated

# %% [markdown]
# # Simple returns and log returns

# %%
df = pd.DataFrame(index=[2016,2017,2018], data=[100,50,95], columns=["Price"])
df
# Out:
#       Price
# 2016    100
# 2017     50
# 2018     95

# %%
simplereturns = df.pct_change().dropna()
simplereturns
# Out:
#       Price
# 2017   -0.5
# 2018    0.9

# %%
simplereturns.describe().T
# Out:
#        count  mean       std  min   25%  50%   75%  max
# Price    2.0   0.2  0.989949 -0.5 -0.15  0.2  0.55  0.9

# %%
simplereturns.mean()
# Out:
# Price    0.2
# dtype: float64

# %%
100*1.2*1. #mean retursn is misleading
# Out:
# 144.0

# %%
logreturns = np.log(df/df.shift(1))
logreturns
# Out:
#          Price
# 2016       NaN
# 2017 -0.693147
# 2018  0.641854

# %%
logreturns.mean()
# Out:
# Price   -0.025647
# dtype: float64

# %%
100*np.exp(logreturns.mean()*2)   # same as 95, this is more accurate
# Out:
# Price    95.0
# dtype: float64

# %%
SPY = yf.download("SPY")
SPY.to_pickle('SPY.pickle')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
spy = pd.read_pickle('SPY.pickle')
spy.head()
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 1993-01-29  43.96875  43.96875  43.75000  43.93750  25.122337  1003200
# 1993-02-01  43.96875  44.25000  43.96875  44.25000  25.301025   480500
# 1993-02-02  44.21875  44.37500  44.12500  44.34375  25.354639   201300
# 1993-02-03  44.40625  44.84375  44.37500  44.81250  25.622643   529400
# 1993-02-04  44.96875  45.09375  44.46875  45.00000  25.729841   531500

# %%
spy = SPY.Close.to_frame() # easier than ["Close"]
spy
# Out:
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-04-14  412.459991
# 2023-04-17  413.940002
# 2023-04-18  414.209991
# 2023-04-19  414.140015
# 2023-04-20  411.880005
#
# [7611 rows x 1 columns]

# %%
spy.plot(figsize=(13,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy.rolling(window=10).max()
# Out:
#                  Close
# Date
# 1993-01-29         NaN
# 1993-02-01         NaN
# 1993-02-02         NaN
# 1993-02-03         NaN
# 1993-02-04         NaN
# ...                ...
# 2023-04-14  413.470001
# 2023-04-17  413.940002
# 2023-04-18  414.209991
# 2023-04-19  414.209991
# 2023-04-20  414.209991
#
# [7611 rows x 1 columns]

# %%
spy.rolling(window=10, min_periods=5).max().head() #need min period of 5 then start calculating
# Out:
#             Close
# Date
# 1993-01-29    NaN
# 1993-02-01    NaN
# 1993-02-02    NaN
# 1993-02-03    NaN
# 1993-02-04   45.0

# %%
spy_roll = spy.rolling(window=50)
spy_roll = spy_roll.mean()
spy_roll.dropna()
# Out:
#                  Close
# Date
# 1993-04-12   44.687500
# 1993-04-13   44.708750
# 1993-04-14   44.722500
# 1993-04-15   44.734375
# 1993-04-16   44.736875
# ...                ...
# 2023-04-14  402.437001
# 2023-04-17  402.380201
# 2023-04-18  402.417401
# 2023-04-19  402.503601
# 2023-04-20  402.437401
#
# [7562 rows x 1 columns]

# %%
spy.rolling(window=50).median().dropna()
# Out:
#                  Close
# Date
# 1993-04-12   44.875000
# 1993-04-13   44.875000
# 1993-04-14   44.890625
# 1993-04-15   44.906250
# 1993-04-16   44.921875
# ...                ...
# 2023-04-14  402.525009
# 2023-04-17  402.525009
# 2023-04-18  402.525009
# 2023-04-19  402.525009
# 2023-04-20  402.525009
#
# [7562 rows x 1 columns]

# %% [markdown]
# ## SIMPLE MA

# %%
spy["SMA50"] = spy.rolling(window=50,min_periods=50).mean()
spy.dropna()
# Out:
#                  Close       SMA50
# Date
# 1993-04-12   44.906250   44.687500
# 1993-04-13   45.000000   44.708750
# 1993-04-14   44.937500   44.722500
# 1993-04-15   44.937500   44.734375
# 1993-04-16   44.937500   44.736875
# ...                ...         ...
# 2023-04-14  412.459991  402.437001
# 2023-04-17  413.940002  402.380201
# 2023-04-18  414.209991  402.417401
# 2023-04-19  414.140015  402.503601
# 2023-04-20  411.880005  402.437401
#
# [7562 rows x 2 columns]

# %%
spy.plot(figsize=(13,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy["SMA200"] = spy.Close.rolling(window=200,min_periods=200).mean()
spy.dropna()
spy.plot(figsize=(13,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
spy
# Out:
#                  Close       SMA50      SMA200
# Date
# 1993-01-29   43.937500         NaN         NaN
# 1993-02-01   44.250000         NaN         NaN
# 1993-02-02   44.343750         NaN         NaN
# 1993-02-03   44.812500         NaN         NaN
# 1993-02-04   45.000000         NaN         NaN
# ...                ...         ...         ...
# 2023-04-14  412.459991  402.437001  394.072350
# 2023-04-17  413.940002  402.380201  394.240350
# 2023-04-18  414.209991  402.417401  394.425150
# 2023-04-19  414.140015  402.503601  394.589651
# 2023-04-20  411.880005  402.437401  394.739251
#
# [7611 rows x 3 columns]

# %% [markdown]
# # EXPONENTIAL MOVING AVERAGE

# %%
spy["EMA13"] = spy.Close.ewm(span=13,min_periods=13).mean()
spy.dropna()
# Out:
#                  Close       SMA50      SMA200       EMA13
# Date
# 1993-11-11   46.375000   46.269375   45.205937   46.386194
# 1993-11-12   46.593750   46.274375   45.219219   46.415845
# 1993-11-15   46.562500   46.278125   45.230781   46.436796
# 1993-11-16   46.781250   46.292500   45.242969   46.486003
# 1993-11-17   46.531250   46.305000   45.251562   46.492467
# ...                ...         ...         ...         ...
# 2023-04-14  412.459991  402.437001  394.072350  407.470230
# 2023-04-17  413.940002  402.380201  394.240350  408.394483
# 2023-04-18  414.209991  402.417401  394.425150  409.225270
# 2023-04-19  414.140015  402.503601  394.589651  409.927377
# 2023-04-20  411.880005  402.437401  394.739251  410.206323
#
# [7412 rows x 4 columns]

# %%
spy.plot(figsize=(13,8), fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %% [markdown]
# # DAY index

# %%
spy["Day"]=spy.index.day_name()
spy
# Out:
#                  Close       SMA50      SMA200       EMA13        Day
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday
# ...                ...         ...         ...         ...        ...
# 2023-04-14  412.459991  402.437001  394.072350  407.470230     Friday
# 2023-04-17  413.940002  402.380201  394.240350  408.394483     Monday
# 2023-04-18  414.209991  402.417401  394.425150  409.225270    Tuesday
# 2023-04-19  414.140015  402.503601  394.589651  409.927377  Wednesday
# 2023-04-20  411.880005  402.437401  394.739251  410.206323   Thursday
#
# [7611 rows x 5 columns]

# %%
spy["Qtr"]=spy.index.quarter
spy
# Out:
#                  Close       SMA50      SMA200       EMA13        Day  Qtr
# Date
# 1993-01-29   43.937500         NaN         NaN         NaN     Friday    1
# 1993-02-01   44.250000         NaN         NaN         NaN     Monday    1
# 1993-02-02   44.343750         NaN         NaN         NaN    Tuesday    1
# 1993-02-03   44.812500         NaN         NaN         NaN  Wednesday    1
# 1993-02-04   45.000000         NaN         NaN         NaN   Thursday    1
# ...                ...         ...         ...         ...        ...  ...
# 2023-04-14  412.459991  402.437001  394.072350  407.470230     Friday    2
# 2023-04-17  413.940002  402.380201  394.240350  408.394483     Monday    2
# 2023-04-18  414.209991  402.417401  394.425150  409.225270    Tuesday    2
# 2023-04-19  414.140015  402.503601  394.589651  409.927377  Wednesday    2
# 2023-04-20  411.880005  402.437401  394.739251  410.206323   Thursday    2
#
# [7611 rows x 6 columns]

# %% [markdown]
# # RE INDEX

# %%
SPY = yf.download("SPY")
SPY.to_pickle('SPY.pickle')
spy = pd.read_pickle('SPY.pickle')
spy = spy.Close.to_frame()
spy
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Close
# Date
# 1993-01-29   43.937500
# 1993-02-01   44.250000
# 1993-02-02   44.343750
# 1993-02-03   44.812500
# 1993-02-04   45.000000
# ...                ...
# 2023-04-14  412.459991
# 2023-04-17  413.940002
# 2023-04-18  414.209991
# 2023-04-19  414.140015
# 2023-04-20  411.880005
#
# [7611 rows x 1 columns]

# %%
all_days = pd.date_range(start="2010-12-31", end=dt.datetime.today() ,freq="D")
all_days
# Out:
# DatetimeIndex(['2010-12-31', '2011-01-01', '2011-01-02', '2011-01-03',
#                '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07',
#                '2011-01-08', '2011-01-09',
#                ...
#                '2023-04-12', '2023-04-13', '2023-04-14', '2023-04-15',
#                '2023-04-16', '2023-04-17', '2023-04-18', '2023-04-19',
#                '2023-04-20', '2023-04-21'],
#               dtype='datetime64[ns]', length=4495, freq='D')

# %%
spy = spy.reindex(all_days)
spy
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01         NaN
# 2011-01-02         NaN
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2023-04-17  413.940002
# 2023-04-18  414.209991
# 2023-04-19  414.140015
# 2023-04-20  411.880005
# 2023-04-21         NaN
#
# [4495 rows x 1 columns]

# %% [markdown]
# # Forward and Backfill

# %%
spy.fillna(method="ffill") #forward fill
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  125.750000
# 2011-01-02  125.750000
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2023-04-17  413.940002
# 2023-04-18  414.209991
# 2023-04-19  414.140015
# 2023-04-20  411.880005
# 2023-04-21  411.880005
#
# [4495 rows x 1 columns]

# %%
spy.fillna(method="bfill")
# Out:
#                  Close
# 2010-12-31  125.750000
# 2011-01-01  127.050003
# 2011-01-02  127.050003
# 2011-01-03  127.050003
# 2011-01-04  126.980003
# ...                ...
# 2023-04-17  413.940002
# 2023-04-18  414.209991
# 2023-04-19  414.140015
# 2023-04-20  411.880005
# 2023-04-21         NaN
#
# [4495 rows x 1 columns]

# %% [markdown]
# # Interval

# %% [markdown]
#  period : str
#         Valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
#         Either Use period parameter or use start and end
#     interval : str
#         Valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo

# %%
SPY = yf.download("SPY",interval="1wk")     
SPY.to_pickle('SPY.pickle')
spy = pd.read_pickle('SPY.pickle')
spy["Day"]=spy.index.day_name()
spy
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1993-01-25   43.968750   43.968750   43.750000   43.937500   25.122341
# 1993-02-01   43.968750   45.093750   43.968750   44.968750   25.711987
# 1993-02-08   44.968750   45.125000   44.531250   44.593750   25.497566
# 1993-02-15   44.468750   44.468750   42.812500   43.562500   24.907919
# 1993-02-22   43.687500   44.437500   43.468750   44.406250   25.390362
# ...                ...         ...         ...         ...         ...
# 2023-03-20  390.799988  402.489990  389.399994  395.750000  395.750000
# 2023-03-27  398.119995  409.700012  393.690002  409.390015  409.390015
# 2023-04-03  408.850006  411.920013  405.679993  409.190002  409.190002
# 2023-04-10  406.609985  415.089996  405.970001  412.459991  412.459991
# 2023-04-17  412.369995  415.720001  410.269989  411.880005  411.880005
#
#                Volume     Day
# Date
# ...

# %% [markdown]
# # Cumulative Returns, Drawdowns

# %%
aapl = yf.download("AAPL")
aapl.to_pickle("aapl.pickle")
aapl = pd.read_pickle("aapl.pickle")
aapl
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099722
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094519
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087582
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089749
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092351
# ...                ...         ...         ...         ...         ...
# 2023-04-14  164.589996  166.320007  163.820007  165.210007  165.210007
# 2023-04-17  165.089996  165.389999  164.029999  165.229996  165.229996
# 2023-04-18  166.100006  167.410004  165.649994  166.470001  166.470001
# 2023-04-19  165.800003  168.160004  165.539993  167.630005  167.630005
# 2023-04-20  166.089996  167.869995  165.559998  166.649994  166.649994
#
#                Volume
# Date
# ...

# %%
aapl = aapl.Close.to_frame()
aapl
# Out:
#                  Close
# Date
# 1980-12-15    0.121652
# 1980-12-16    0.112723
# 1980-12-17    0.115513
# 1980-12-18    0.118862
# 1980-12-19    0.126116
# ...                ...
# 2023-04-14  165.210007
# 2023-04-17  165.229996
# 2023-04-18  166.470001
# 2023-04-19  167.630005
# 2023-04-20  166.649994
#
# [10677 rows x 1 columns]

# %%
aapl["d_returns"] = np.log(aapl.div(aapl.shift(1)))
aapl.head()
# Out:
#                Close  d_returns
# Date
# 1980-12-15  0.121652        NaN
# 1980-12-16  0.112723  -0.076231
# 1980-12-17  0.115513   0.024450
# 1980-12-18  0.118862   0.028580
# 1980-12-19  0.126116   0.059239

# %%
aapl.dropna(inplace=True)
aapl
# Out:
#                  Close  d_returns
# Date
# 1980-12-16    0.112723  -0.076231
# 1980-12-17    0.115513   0.024450
# 1980-12-18    0.118862   0.028580
# 1980-12-19    0.126116   0.059239
# 1980-12-22    0.132254   0.047522
# ...                ...        ...
# 2023-04-14  165.210007  -0.002116
# 2023-04-17  165.229996   0.000121
# 2023-04-18  166.470001   0.007477
# 2023-04-19  167.630005   0.006944
# 2023-04-20  166.649994  -0.005863
#
# [10676 rows x 2 columns]

# %%
aapl.d_returns.sum()
# Out:
# 7.222486540265894

# %%
np.exp(aapl.d_returns.sum())  #if $1 invested in 1980, it is worth this amt today
# Out:
# 1369.8911187048227

# %% [markdown]
# # Cumulative returns

# %%
aapl["cumreturns"]=aapl.d_returns.cumsum().apply(np.exp)

# %%
aapl
# Out:
#                  Close  d_returns   cumreturns
# Date
# 1980-12-16    0.112723  -0.076231     0.926602
# 1980-12-17    0.115513   0.024450     0.949536
# 1980-12-18    0.118862   0.028580     0.977066
# 1980-12-19    0.126116   0.059239     1.036695
# 1980-12-22    0.132254   0.047522     1.087150
# ...                ...        ...          ...
# 2023-04-14  165.210007  -0.002116  1358.054181
# 2023-04-17  165.229996   0.000121  1358.218494
# 2023-04-18  166.470001   0.007477  1368.411548
# 2023-04-19  167.630005   0.006944  1377.946975
# 2023-04-20  166.649994  -0.005863  1369.891119
#
# [10676 rows x 3 columns]

# %%
aapl.cumreturns.plot(figsize=(12,8), title="AAPL buy and Hold", fontsize= 12)
# Out:
# <Axes: title={'center': 'AAPL buy and Hold'}, xlabel='Date'>

# %%
aapl.d_returns.mean()*252
# Out:
# 0.1704820727001691

# %%
aapl.d_returns.std()*np.sqrt(252)
# Out:
# 0.45457242662469943

# %% [markdown]
# # How to calculate drawdowns

# %%
aapl["cum_max"] = aapl.cumreturns.cummax()

# %%
aapl
# Out:
#                  Close  d_returns   cumreturns      cum_max
# Date
# 1980-12-16    0.112723  -0.076231     0.926602     0.926602
# 1980-12-17    0.115513   0.024450     0.949536     0.949536
# 1980-12-18    0.118862   0.028580     0.977066     0.977066
# 1980-12-19    0.126116   0.059239     1.036695     1.036695
# 1980-12-22    0.132254   0.047522     1.087150     1.087150
# ...                ...        ...          ...          ...
# 2023-04-14  165.210007  -0.002116  1358.054181  1496.152920
# 2023-04-17  165.229996   0.000121  1358.218494  1496.152920
# 2023-04-18  166.470001   0.007477  1368.411548  1496.152920
# 2023-04-19  167.630005   0.006944  1377.946975  1496.152920
# 2023-04-20  166.649994  -0.005863  1369.891119  1496.152920
#
# [10676 rows x 4 columns]

# %%
aapl[["cumreturns", "cum_max"]].plot(figsize=(12,8), title="AAPL buy and Hold + cummax", fontsize= 12)
plt.show()

# %% [markdown]
# # Drawdowns

# %%
aapl["drawdown"] = aapl["cum_max"]-aapl["cumreturns"]
aapl
# Out:
#                  Close  d_returns   cumreturns      cum_max    drawdown
# Date
# 1980-12-16    0.112723  -0.076231     0.926602     0.926602    0.000000
# 1980-12-17    0.115513   0.024450     0.949536     0.949536    0.000000
# 1980-12-18    0.118862   0.028580     0.977066     0.977066    0.000000
# 1980-12-19    0.126116   0.059239     1.036695     1.036695    0.000000
# 1980-12-22    0.132254   0.047522     1.087150     1.087150    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-04-14  165.210007  -0.002116  1358.054181  1496.152920  138.098739
# 2023-04-17  165.229996   0.000121  1358.218494  1496.152920  137.934426
# 2023-04-18  166.470001   0.007477  1368.411548  1496.152920  127.741372
# 2023-04-19  167.630005   0.006944  1377.946975  1496.152920  118.205945
# 2023-04-20  166.649994  -0.005863  1369.891119  1496.152920  126.261801
#
# [10676 rows x 5 columns]

# %%
aapl.drawdown.max()
# Out:
# 468.4674154688619

# %%
aapl.drawdown.idxmax() #date it happened
# Out:
# Timestamp('2023-01-05 00:00:00')

# %%
aapl.loc[(aapl.index=='2023-01-05')]
# Out:
#                  Close  d_returns   cumreturns     cum_max    drawdown
# Date
# 2023-01-05  125.019997  -0.010661  1027.685505  1496.15292  468.467415

# %%
aapl.loc[(aapl.index<='2023-01-05')]
# Out:
#                  Close  d_returns   cumreturns      cum_max    drawdown
# Date
# 1980-12-16    0.112723  -0.076231     0.926602     0.926602    0.000000
# 1980-12-17    0.115513   0.024450     0.949536     0.949536    0.000000
# 1980-12-18    0.118862   0.028580     0.977066     0.977066    0.000000
# 1980-12-19    0.126116   0.059239     1.036695     1.036695    0.000000
# 1980-12-22    0.132254   0.047522     1.087150     1.087150    0.000000
# ...                ...        ...          ...          ...         ...
# 2022-12-29  129.610001   0.027931  1065.416113  1496.152920  430.736807
# 2022-12-30  129.929993   0.002466  1068.046502  1496.152920  428.106418
# 2023-01-03  125.070000  -0.038122  1028.096538  1496.152920  468.056382
# 2023-01-04  126.360001   0.010261  1038.700564  1496.152920  457.452356
# 2023-01-05  125.019997  -0.010661  1027.685505  1496.152920  468.467415
#
# [10604 rows x 5 columns]

# %%
# % drawdown
aapl["drawdown pct"] = (aapl["cum_max"]-aapl["cumreturns"])/aapl["cum_max"]
aapl
# Out:
#                  Close  d_returns   cumreturns      cum_max    drawdown  \
# Date
# 1980-12-16    0.112723  -0.076231     0.926602     0.926602    0.000000
# 1980-12-17    0.115513   0.024450     0.949536     0.949536    0.000000
# 1980-12-18    0.118862   0.028580     0.977066     0.977066    0.000000
# 1980-12-19    0.126116   0.059239     1.036695     1.036695    0.000000
# 1980-12-22    0.132254   0.047522     1.087150     1.087150    0.000000
# ...                ...        ...          ...          ...         ...
# 2023-04-14  165.210007  -0.002116  1358.054181  1496.152920  138.098739
# 2023-04-17  165.229996   0.000121  1358.218494  1496.152920  137.934426
# 2023-04-18  166.470001   0.007477  1368.411548  1496.152920  127.741372
# 2023-04-19  167.630005   0.006944  1377.946975  1496.152920  118.205945
# 2023-04-20  166.649994  -0.005863  1369.891119  1496.152920  126.261801
#
#             drawdown pct
# Date
# 1980-12-16      0.000000
# 1980-12-17      0.000000
# ...

# %%
aapl["drawdown pct"].max()
# Out:
# 0.8221656792419101

# %%
aapl["drawdown pct"].idxmax()
# Out:
# Timestamp('1997-12-23 00:00:00')

# %%
aapl.loc[(aapl.index<='1997-12-23')]
# Out:
#                Close  d_returns  cumreturns   cum_max  drawdown  drawdown pct
# Date
# 1980-12-16  0.112723  -0.076231    0.926602  0.926602  0.000000      0.000000
# 1980-12-17  0.115513   0.024450    0.949536  0.949536  0.000000      0.000000
# 1980-12-18  0.118862   0.028580    0.977066  0.977066  0.000000      0.000000
# 1980-12-19  0.126116   0.059239    1.036695  1.036695  0.000000      0.000000
# 1980-12-22  0.132254   0.047522    1.087150  1.087150  0.000000      0.000000
# ...              ...        ...         ...       ...       ...           ...
# 1997-12-17  0.124442  -0.026549    1.022934  5.339444  4.316509      0.808419
# 1997-12-18  0.123326  -0.009008    1.013761  5.339444  4.325683      0.810137
# 1997-12-19  0.122210  -0.009090    1.004587  5.339444  4.334857      0.811856
# 1997-12-22  0.118862  -0.027778    0.977066  5.339444  4.362378      0.817010
# 1997-12-23  0.115513  -0.028580    0.949536  5.339444  4.389907      0.822166
#
# [4305 rows x 6 columns]

# %% [markdown]
# # SMA STRAT

# %%
data = aapl.loc[(aapl.index>='1991-01-01')]
data
# Out:
#                  Close  d_returns   cumreturns      cum_max    drawdown  \
# Date
# 1991-01-02    0.388393   0.011560     3.192656     4.348617    1.155961
# 1991-01-03    0.383929  -0.011560     3.155961     4.348617    1.192656
# 1991-01-04    0.386161   0.005797     3.174309     4.348617    1.174309
# 1991-01-07    0.386161   0.000000     3.174309     4.348617    1.174309
# 1991-01-08    0.386161   0.000000     3.174309     4.348617    1.174309
# ...                ...        ...          ...          ...         ...
# 2023-04-14  165.210007  -0.002116  1358.054181  1496.152920  138.098739
# 2023-04-17  165.229996   0.000121  1358.218494  1496.152920  137.934426
# 2023-04-18  166.470001   0.007477  1368.411548  1496.152920  127.741372
# 2023-04-19  167.630005   0.006944  1377.946975  1496.152920  118.205945
# 2023-04-20  166.649994  -0.005863  1369.891119  1496.152920  126.261801
#
#             drawdown pct
# Date
# 1991-01-02      0.265823
# 1991-01-03      0.274261
# ...

# %%
data = aapl.Close.loc[(aapl.index>='1991-01-01')]
data = data.to_frame()
data
# Out:
#                  Close
# Date
# 1991-01-02    0.388393
# 1991-01-03    0.383929
# 1991-01-04    0.386161
# 1991-01-07    0.386161
# 1991-01-08    0.386161
# ...                ...
# 2023-04-14  165.210007
# 2023-04-17  165.229996
# 2023-04-18  166.470001
# 2023-04-19  167.630005
# 2023-04-20  166.649994
#
# [8137 rows x 1 columns]

# %%
sma_13 = 13
sma_50 = 50

# %%
data["sma_13"] = data.Close.rolling(sma_13).mean()
data["sma_50"] = data.Close.rolling(sma_50).mean()
data
# Out:
#                  Close      sma_13    sma_50
# Date
# 1991-01-02    0.388393         NaN       NaN
# 1991-01-03    0.383929         NaN       NaN
# 1991-01-04    0.386161         NaN       NaN
# 1991-01-07    0.386161         NaN       NaN
# 1991-01-08    0.386161         NaN       NaN
# ...                ...         ...       ...
# 2023-04-14  165.210007  163.046154  155.2216
# 2023-04-17  165.229996  163.629231  155.5098
# 2023-04-18  166.470001  164.067693  155.7492
# 2023-04-19  167.630005  164.473078  156.0672
# 2023-04-20  166.649994  164.607693  156.3072
#
# [8137 rows x 3 columns]

# %%
data.plot(figsize=(12,8), title = "AAPL - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL - SMA13 | SMA50'}, xlabel='Date'>

# %%
data.loc["2023"].plot(figsize=(12,8), title = "AAPL - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12)
# Out:
# <Axes: title={'center': 'AAPL - SMA13 | SMA50'}, xlabel='Date'>

# %%
data.dropna(inplace=True)
data
# Out:
#                  Close      sma_13      sma_50
# Date
# 1991-03-13    0.591518    0.548678    0.492232
# 1991-03-14    0.582589    0.553657    0.496116
# 1991-03-15    0.591518    0.559152    0.500268
# 1991-03-18    0.604911    0.565676    0.504643
# 1991-03-19    0.620536    0.574090    0.509330
# ...                ...         ...         ...
# 2023-04-14  165.210007  163.046154  155.221600
# 2023-04-17  165.229996  163.629231  155.509800
# 2023-04-18  166.470001  164.067693  155.749200
# 2023-04-19  167.630005  164.473078  156.067200
# 2023-04-20  166.649994  164.607693  156.307200
#
# [8088 rows x 3 columns]

# %%
data["pos"] = np.where(data["sma_13"]>data["sma_50"],1,-1)    #when condition is right, > 1
data
# Out:
#                  Close      sma_13      sma_50  pos
# Date
# 1991-03-13    0.591518    0.548678    0.492232    1
# 1991-03-14    0.582589    0.553657    0.496116    1
# 1991-03-15    0.591518    0.559152    0.500268    1
# 1991-03-18    0.604911    0.565676    0.504643    1
# 1991-03-19    0.620536    0.574090    0.509330    1
# ...                ...         ...         ...  ...
# 2023-04-14  165.210007  163.046154  155.221600    1
# 2023-04-17  165.229996  163.629231  155.509800    1
# 2023-04-18  166.470001  164.067693  155.749200    1
# 2023-04-19  167.630005  164.473078  156.067200    1
# 2023-04-20  166.649994  164.607693  156.307200    1
#
# [8088 rows x 4 columns]

# %%
data.loc[:,["sma_13","sma_50", "pos"]].plot(figsize=(12,8), title = "AAPL - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12, secondary_y="pos")
# Out:
# <Axes: title={'center': 'AAPL - SMA13 | SMA50'}, xlabel='Date'>

# %%
data.loc["2022",["sma_13","sma_50", "pos"]].plot(figsize=(12,8), title = "AAPL - SMA{} | SMA{}".format(sma_s,sma_l), fontsize=12, secondary_y="pos")
# Out:
# <Axes: title={'center': 'AAPL - SMA13 | SMA50'}, xlabel='Date'>

# %%
data["returnsb&h"] = np.log(data.Close.div(data.Close.shift(1)))
data
# Out:
#                  Close      sma_13      sma_50  pos  returnsb&h
# Date
# 1991-03-13    0.591518    0.548678    0.492232    1         NaN
# 1991-03-14    0.582589    0.553657    0.496116    1   -0.015210
# 1991-03-15    0.591518    0.559152    0.500268    1    0.015210
# 1991-03-18    0.604911    0.565676    0.504643    1    0.022389
# 1991-03-19    0.620536    0.574090    0.509330    1    0.025502
# ...                ...         ...         ...  ...         ...
# 2023-04-14  165.210007  163.046154  155.221600    1   -0.002116
# 2023-04-17  165.229996  163.629231  155.509800    1    0.000121
# 2023-04-18  166.470001  164.067693  155.749200    1    0.007477
# 2023-04-19  167.630005  164.473078  156.067200    1    0.006944
# 2023-04-20  166.649994  164.607693  156.307200    1   -0.005863
#
# [8088 rows x 5 columns]

# %%
data["strategy"] = data["returnsb&h"]*data.pos.shift(1)
data
# Out:
#                  Close      sma_13      sma_50  pos  returnsb&h  strategy
# Date
# 1991-03-13    0.591518    0.548678    0.492232    1         NaN       NaN
# 1991-03-14    0.582589    0.553657    0.496116    1   -0.015210 -0.015210
# 1991-03-15    0.591518    0.559152    0.500268    1    0.015210  0.015210
# 1991-03-18    0.604911    0.565676    0.504643    1    0.022389  0.022389
# 1991-03-19    0.620536    0.574090    0.509330    1    0.025502  0.025502
# ...                ...         ...         ...  ...         ...       ...
# 2023-04-14  165.210007  163.046154  155.221600    1   -0.002116 -0.002116
# 2023-04-17  165.229996  163.629231  155.509800    1    0.000121  0.000121
# 2023-04-18  166.470001  164.067693  155.749200    1    0.007477  0.007477
# 2023-04-19  167.630005  164.473078  156.067200    1    0.006944  0.006944
# 2023-04-20  166.649994  164.607693  156.307200    1   -0.005863 -0.005863
#
# [8088 rows x 6 columns]

# %%
data["strategy"].plot(figsize=(12,8), title= "Strategy returns", fontsize=12)
# Out:
# <Axes: title={'center': 'Strategy returns'}, xlabel='Date'>

# %%
data.dropna(inplace=True)
data[["returnsb&h","strategy"]].sum()
# Out:
# returnsb&h    5.640959
# strategy      3.354294
# dtype: float64

# %% [markdown]
# # Absolute performance

# %%
data[["returnsb&h","strategy"]].sum().apply(np.exp) # what $1 will be
# Out:
# returnsb&h    281.732759
# strategy       28.625391
# dtype: float64

# %%
data[["returnsb&h","strategy"]].std()*np.sqrt(252)  #annual std
# Out:
# returnsb&h    0.44067
# strategy      0.44076
# dtype: float64

# %%
data.Close.plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Strat dont go short, long bias, prev strat includes going short

# %%
data["pos2"] = np.where(data["sma_13"]>data["sma_50"],1,0)    #when condition is right, > 1
data["strategy2"] = data["returnsb&h"]*data.pos2.shift(1)
data.dropna(inplace=True)
data
# Out:
#                  Close      sma_13      sma_50  pos  returnsb&h  strategy  \
# Date
# 1991-03-18    0.604911    0.565676    0.504643    1    0.022389  0.022389
# 1991-03-19    0.620536    0.574090    0.509330    1    0.025502  0.025502
# 1991-03-20    0.604911    0.580958    0.513705    1   -0.025502 -0.025502
# 1991-03-21    0.578125    0.585337    0.517188    1   -0.045291 -0.045291
# 1991-03-22    0.564732    0.585422    0.520067    1   -0.023439 -0.023439
# ...                ...         ...         ...  ...         ...       ...
# 2023-04-14  165.210007  163.046154  155.221600    1   -0.002116 -0.002116
# 2023-04-17  165.229996  163.629231  155.509800    1    0.000121  0.000121
# 2023-04-18  166.470001  164.067693  155.749200    1    0.007477  0.007477
# 2023-04-19  167.630005  164.473078  156.067200    1    0.006944  0.006944
# 2023-04-20  166.649994  164.607693  156.307200    1   -0.005863 -0.005863
#
#             pos2  strategy2
# Date
# 1991-03-18     1   0.022389
# ...

# %%
data[["returnsb&h","strategy2"]].sum()
# Out:
# returnsb&h    5.640959
# strategy2     4.497627
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].sum().apply(np.exp) # what $1 will be
# Out:
# returnsb&h    281.732759
# strategy2      89.803733
# dtype: float64

# %%
data[["returnsb&h","strategy2"]].std()*np.sqrt(252)  #annual std
# Out:
# returnsb&h    0.440708
# strategy2     0.328365
# dtype: float64

# %%
data[["strategy","strategy2"]].sum()
# Out:
# strategy     3.354294
# strategy2    4.497627
# dtype: float64

# %%
data[["strategy","strategy2"]].std()*np.sqrt(252)  #annual std
# Out:
# strategy     0.440798
# strategy2    0.328365
# dtype: float64

# %% [markdown]
# ## spy["EMA13"] = spy.Close.ewm(span=13,min_periods=13).mean()

# %% [markdown]
# # Create function

# %%
def test_strat(stock, start, end, EMA):
    df =yf.download(stock,start=start, end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["pos"]=np.where(data["EMA4"]>data["EMA13"],1,-1)
    data["strategy"]=data["returns"]*data.pos.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std=data["strategy"].std()*np.sqrt(252)
    
    return ret,std

# %%
def test_strat(stock, start, end, EMA):
    df =yf.download(stock,start=start, end=end)
    data=df.Close.to_frame()
    data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["EMA4"] = spy.Close.ewm(span=4,min_periods=4).mean()
    data["EMA13"] = spy.Close.ewm(span=13,min_periods=13).mean()
 #   data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
  #  data["SMA_l"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["pos"]=np.where(data["EMA4"]>data["EMA13"],1,-1)
    data["strategy"]=data["returns"]*data.pos.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["strategy"].sum())
    std=data["strategy"].std()*np.sqrt(252)
    
    return ret,std

# %%
test_strat("AAPL", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.3755219177367861, 0.4068873228066586)

# %%
test_strat("MSFT", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.0938245785634118, 0.3928761678081194)

# %%
test_strat("TSLA", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (3.95983075102937, 0.8880368522313524)

# %%
test_strat("NVDA", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.3480036476880493, 0.6021842972158871)

# %%
test_strat("SMH", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.3217861912840316, 0.4259406989892836)

# %%
test_strat("SPY", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.2159298325809968, 0.27882679489175527)

# %%
test_strat("AAPL", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.3755219177367861, 0.4068873228066586)

# %%
test_strat("MSFT", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.0938245785634118, 0.3928761678081194)

# %%
test_strat("NVDA", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.3480036476880493, 0.6021842972158871)

# %%
test_strat("SPY", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (1.2159298325809968, 0.27882679489175527)

# %%
test_strat("TSLA", "2020-01-01", "2023-04-21", (4,13))
# Out:
# [*********************100%***********************]  1 of 1 completed
# (3.95983075102937, 0.8880368522313524)

# %% [markdown]
# # Create own Class

# %%
class SMABacktester():
    def __init__(self,symbol, SMA_S, SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
        
    def get_data(self):
            df = yf.download(self.symbol,start=self.start, end=self.end)
            data=df.Close.to_frame()
            data["returns"]=np.log(data.Close.div(data.Close.shift(1)))
            data["SMA_S"]=data.Close.rolling(self.SMA_S).mean()
            data["SMA_L"]=data.Close.rolling(self.SMA_L).mean()
            data.dropna(inplace=True)
            self.data2=data

            return data
        
    def test_results(self):
            data=self.data2.copy().dropna()
            data["pos"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
            data["strategy"]=data["returns"]*data.pos.shift(1)
            data.dropna(inplace=True)
            data["returnsbh"]=data["returns"].cumsum().apply(np.exp)
            data["returnstrat"]=data["strategy"].cumsum().apply(np.exp)
            perf=data["returnstrat"].iloc[-1]
            outperf=perf-data["returnsbh"].iloc[-1]
            self.results=data
            
            
            ret=np.exp(data["strategy"].sum())
            std=data["strategy"].std()*np.sqrt(252)
            
           # return ret,std
            return round(perf,6), round(outperf,6)
        
        
    def plot_results(self):
        if self.results is None:
            print("Run the test please")
        else:
            title="{}| SMA_S={} | SMA_L{}".format(self.symbol, self.SMA_S, self.SMA_L)
            self.results[["returnsbh", "returnstrat"]].plot(title=title, figsize=(12,8))

# %%
tester = SMABacktester("SPY", 4, 13, "2020-01-01", "2023-04-22")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester.test_results()  #per, outperf
# Out:
# (1.223371, -0.020818)

# %%
tester.plot_results()

# %% [markdown]
# ## API

# %%
stocks.to_csv("sti.csv")

# %%
stocks = pd.read_csv("stocks_data.csv", header=[0,1], index_col=[0], parse_dates=[0])
#stocks = stocks.dropna().squeeze()
stocks.index.day_name()
stocks.insert(0, "Day", stocks.index.day_name())
stocks.tail()
# Out:
#                   Day Adj Close                                              \
#                          BN4.SI C38U.SI     D05.SI G13.SI O39.SI     U11.SI
# Date
# 2022-11-30  Wednesday      7.54    2.07  35.189999  0.880  12.44  31.200001
# 2022-12-01   Thursday      7.58    2.06  34.950001  0.880  12.35  31.330000
# 2022-12-02     Friday      7.64    2.02  34.470001  0.880  12.21  30.910000
# 2022-12-05     Monday      7.60    2.04  34.500000  0.885  12.18  31.000000
# 2022-12-06    Tuesday      7.43    2.05  34.000000  0.890  12.20  30.799999
#
#                    Close          ...   Open                     Volume  \
#            U96.SI BN4.SI C38U.SI  ... O39.SI     U11.SI U96.SI   BN4.SI
# Date                              ...
# 2022-11-30   3.20   7.54    2.07  ...  12.41  31.000000   3.23  6204500
# 2022-12-01   3.24   7.58    2.06  ...  12.47  31.290001   3.23  3553000
# 2022-12-02   3.28   7.64    2.02  ...  12.37  31.330000   3.24  3911900
# ...

# %%
stocks.columns
# Out:
# MultiIndex([(      'Day',        ''),
#             ('Adj Close',  'BN4.SI'),
#             ('Adj Close', 'C38U.SI'),
#             ('Adj Close',  'D05.SI'),
#             ('Adj Close',  'G13.SI'),
#             ('Adj Close',  'O39.SI'),
#             ('Adj Close',  'U11.SI'),
#             ('Adj Close',  'U96.SI'),
#             (    'Close',  'BN4.SI'),
#             (    'Close', 'C38U.SI'),
#             (    'Close',  'D05.SI'),
#             (    'Close',  'G13.SI'),
#             (    'Close',  'O39.SI'),
#             (    'Close',  'U11.SI'),
#             (    'Close',  'U96.SI'),
#             (     'High',  'BN4.SI'),
#             (     'High', 'C38U.SI'),
#             (     'High',  'D05.SI'),
#             (     'High',  'G13.SI'),
#             (     'High',  'O39.SI'),
#             (     'High',  'U11.SI'),
#             (     'High',  'U96.SI'),
#             (      'Low',  'BN4.SI'),
#             (      'Low', 'C38U.SI'),
#             (      'Low',  'D05.SI'),
# ...

# %%
#convert multiindex to 1 tuple
stocks.columns=stocks.columns.to_flat_index()
stocks.columns
# Out:
# Index([             ('Day', ''),  ('Adj Close', 'BN4.SI'),
#        ('Adj Close', 'C38U.SI'),  ('Adj Close', 'D05.SI'),
#         ('Adj Close', 'G13.SI'),  ('Adj Close', 'O39.SI'),
#         ('Adj Close', 'U11.SI'),  ('Adj Close', 'U96.SI'),
#             ('Close', 'BN4.SI'),     ('Close', 'C38U.SI'),
#             ('Close', 'D05.SI'),      ('Close', 'G13.SI'),
#             ('Close', 'O39.SI'),      ('Close', 'U11.SI'),
#             ('Close', 'U96.SI'),       ('High', 'BN4.SI'),
#             ('High', 'C38U.SI'),       ('High', 'D05.SI'),
#              ('High', 'G13.SI'),       ('High', 'O39.SI'),
#              ('High', 'U11.SI'),       ('High', 'U96.SI'),
#               ('Low', 'BN4.SI'),       ('Low', 'C38U.SI'),
#               ('Low', 'D05.SI'),        ('Low', 'G13.SI'),
#               ('Low', 'O39.SI'),        ('Low', 'U11.SI'),
#               ('Low', 'U96.SI'),       ('Open', 'BN4.SI'),
#             ('Open', 'C38U.SI'),       ('Open', 'D05.SI'),
# ...

# %%
stocks.tail()
# Out:
#                   Day Adj Close                                              \
#                          BN4.SI C38U.SI     D05.SI G13.SI O39.SI     U11.SI
# Date
# 2022-11-30  Wednesday      7.54    2.07  35.189999  0.880  12.44  31.200001
# 2022-12-01   Thursday      7.58    2.06  34.950001  0.880  12.35  31.330000
# 2022-12-02     Friday      7.64    2.02  34.470001  0.880  12.21  30.910000
# 2022-12-05     Monday      7.60    2.04  34.500000  0.885  12.18  31.000000
# 2022-12-06    Tuesday      7.43    2.05  34.000000  0.890  12.20  30.799999
#
#                    Close          ...   Open                     Volume  \
#            U96.SI BN4.SI C38U.SI  ... O39.SI     U11.SI U96.SI   BN4.SI
# Date                              ...
# 2022-11-30   3.20   7.54    2.07  ...  12.41  31.000000   3.23  6204500
# 2022-12-01   3.24   7.58    2.06  ...  12.47  31.290001   3.23  3553000
# 2022-12-02   3.28   7.64    2.02  ...  12.37  31.330000   3.24  3911900
# ...

# %%
#back to og
stocks.columns=pd.MultiIndex.from_tuples(stocks.columns)
stocks.tail()
# Out:
#                   Day Adj Close                                              \
#                          BN4.SI C38U.SI     D05.SI G13.SI O39.SI     U11.SI
# Date
# 2022-11-30  Wednesday      7.54    2.07  35.189999  0.880  12.44  31.200001
# 2022-12-01   Thursday      7.58    2.06  34.950001  0.880  12.35  31.330000
# 2022-12-02     Friday      7.64    2.02  34.470001  0.880  12.21  30.910000
# 2022-12-05     Monday      7.60    2.04  34.500000  0.885  12.18  31.000000
# 2022-12-06    Tuesday      7.43    2.05  34.000000  0.890  12.20  30.799999
#
#                    Close          ...   Open                     Volume  \
#            U96.SI BN4.SI C38U.SI  ... O39.SI     U11.SI U96.SI   BN4.SI
# Date                              ...
# 2022-11-30   3.20   7.54    2.07  ...  12.41  31.000000   3.23  6204500
# 2022-12-01   3.24   7.58    2.06  ...  12.47  31.290001   3.23  3553000
# 2022-12-02   3.28   7.64    2.02  ...  12.37  31.330000   3.24  3911900
# ...

# %%
stocks.describe()
# Out:
#         Adj Close                                                              \
#            BN4.SI     C38U.SI      D05.SI      G13.SI      O39.SI      U11.SI
# count  486.000000  486.000000  486.000000  486.000000  486.000000  486.000000
# mean     5.667012    2.026152   30.043728    0.792190   11.312847   26.187380
# std      0.913493    0.093043    3.031035    0.045568    0.666427    2.465253
# min      4.486271    1.740000   23.340769    0.692415    9.293860   20.843481
# 25%      4.928886    1.958959   28.056456    0.760682   11.035835   24.423764
# 50%      5.108980    2.020553   30.056978    0.789939   11.325858   25.869558
# 75%      6.476702    2.079922   32.465558    0.822949   11.697778   27.922983
# max      7.640000    2.294493   35.691887    0.906361   12.811452   31.519808
#
#                         Close                          ...        Open  \
#            U96.SI      BN4.SI     C38U.SI      D05.SI  ...      O39.SI
# ...

# %%
close=stocks.loc[:,"Adj Close"].copy()
close
# Out:
#               BN4.SI   C38U.SI     D05.SI    G13.SI     O39.SI     U11.SI  \
# Date
# 2021-01-04  4.962365  2.017004  23.489084  0.829223   9.330814  20.954350
# 2021-01-05  4.971521  2.026214  23.498352  0.824402   9.293860  20.852718
# 2021-01-06  4.980677  2.072264  23.340769  0.824402   9.321576  20.843481
# 2021-01-07  5.063078  2.035424  24.147223  0.824402   9.534059  21.434784
# 2021-01-08  5.154634  2.090684  25.417152  0.834045   9.912834  22.358698
# ...              ...       ...        ...       ...        ...        ...
# 2022-11-30  7.540000  2.070000  35.189999  0.880000  12.440000  31.200001
# 2022-12-01  7.580000  2.060000  34.950001  0.880000  12.350000  31.330000
# 2022-12-02  7.640000  2.020000  34.470001  0.880000  12.210000  30.910000
# 2022-12-05  7.600000  2.040000  34.500000  0.885000  12.180000  31.000000
# 2022-12-06  7.430000  2.050000  34.000000  0.890000  12.200000  30.799999
#
#               U96.SI
# Date
# 2021-01-04  1.633868
# 2021-01-05  1.633868
# ...

# %%
stocks["daily_return_pct"] = (stocks["Adj Close"] - stocks["Adj Close"].shift(1)) / stocks["Adj Close"].shift(1)*100
stocks.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'daily_return_pct'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
#normalize it
close.iloc[0,0]
# Out:
# 4.96236515045166

# %%
cols =stocks.columns.tolist()
cols
# Out:
# [('Day', ''),
#  ('Adj Close', 'BN4.SI'),
#  ('Adj Close', 'C38U.SI'),
#  ('Adj Close', 'D05.SI'),
#  ('Adj Close', 'G13.SI'),
#  ('Adj Close', 'O39.SI'),
#  ('Adj Close', 'U11.SI'),
#  ('Adj Close', 'U96.SI'),
#  ('Close', 'BN4.SI'),
#  ('Close', 'C38U.SI'),
#  ('Close', 'D05.SI'),
#  ('Close', 'G13.SI'),
#  ('Close', 'O39.SI'),
#  ('Close', 'U11.SI'),
#  ('Close', 'U96.SI'),
#  ('High', 'BN4.SI'),
#  ('High', 'C38U.SI'),
#  ('High', 'D05.SI'),
#  ('High', 'G13.SI'),
#  ('High', 'O39.SI'),
#  ('High', 'U11.SI'),
#  ('High', 'U96.SI'),
#  ('Low', 'BN4.SI'),
#  ('Low', 'C38U.SI'),
#  ('Low', 'D05.SI'),
#  ('Low', 'G13.SI'),
#  ('Low', 'O39.SI'),
#  ('Low', 'U11.SI'),
#  ('Low', 'U96.SI'),
#  ('Open', 'BN4.SI'),
#  ('Open', 'C38U.SI'),
#  ('Open', 'D05.SI'),
#  ('Open', 'G13.SI'),
#  ('Open', 'O39.SI'),
#  ('Open', 'U11.SI'),
#  ('Open', 'U96.SI'),
#  ('Volume', 'BN4.SI'),
#  ('Volume', 'C38U.SI'),
#  ('Volume', 'D05.SI'),
#  ('Volume', 'G13.SI'),
#  ('Volume', 'O39.SI'),
# ...

# %%
stocks.columns = stocks.columns.str.replace(".SI","")
stocks.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_63252\4215295308.py in <module>
# ----> 1 stocks.columns = stocks.columns.str.replace(".SI","")
#       2 stocks.columns
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
# ...

# %%
cols.rename(columns=trunc_name, inplace=True)
cols

cols = cols[:6] + cols[-1:] + cols[6:8]
s51 = s51[cols]
s51.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_63252\1978103974.py in <module>
# ----> 1 cols.rename(columns=trunc_name, inplace=True)
#       2 cols
#
# AttributeError: 'list' object has no attribute 'rename'

# %%
close.G13
# Out:
#   File "C:\Users\Jonathan\AppData\Local\Temp\ipykernel_63252\703676355.py", line 1
#     close.G13\.SI
#               ^
# SyntaxError: unexpected character after line continuation character

# %%
s51 = s51.dropna().squeeze() 
#compute log returns
s51["log_return"] = np.log(s51["Adj Close"] / s51["Adj Close"].shift(1))*100

#add column for calendar day of month (1-31 & column for year)
s51["day_of_month"] = s51.index.day

s51["year"] = s51.index.year
